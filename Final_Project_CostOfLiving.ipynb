# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv("https://raw.githubusercontent.com/RachmasariAR/CostOfLivingDataset/main/Cost_of_Living_2018.csv")
df2 = pd.read_csv("https://raw.githubusercontent.com/RachmasariAR/CostOfLivingDataset/main/Cost_of_Living_2022.csv")

# %%
df1
# Out:
#                           City  Cost of Living Index  Rent Index  \
# 0            Hamilton, Bermuda                145.43      110.87
# 1          Zurich, Switzerland                141.25       66.14
# 2          Geneva, Switzerland                134.83       71.70
# 3           Basel, Switzerland                130.68       49.68
# 4            Bern, Switzerland                128.03       43.57
# ..                         ...                   ...         ...
# 535               Kochi, India                 24.65        6.31
# 536          Coimbatore, India                 24.61        5.35
# 537          Alexandria, Egypt                 23.78        4.34
# 538         Navi Mumbai, India                 23.44        6.25
# 539  Thiruvananthapuram, India                 20.86        5.10
#
#      Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                            128.76           143.47                  158.75
# ...

# %%
df2
# Out:
#      Rank      Country  Cost of Living Index  Rent Index  \
# 0       1  Afghanistan                 20.37        2.72
# 1       2      Albania                 35.50        8.47
# 2       3      Algeria                 26.87        4.59
# 3       4    Argentina                 34.69        7.71
# 4       5      Armenia                 33.89       11.61
# ..    ...          ...                   ...         ...
# 134   135    Venezuela                 43.20        9.99
# 135   136      Vietnam                 37.48       13.22
# 136   137        Yemen                 53.14        6.71
# 137   138       Zambia                 33.04        9.26
# 138   139     Zimbabwe                 45.68        8.75
#
#      Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                             12.09            14.92                   12.41
# 1                             22.83            29.32                   25.82
# ...

# %%
df2 = df2.drop("Rank", axis=1)

# %%
df1.rename(columns = {"City": "Country"}, inplace=True)
df1
#dalam dolar
# Out:
#                        Country  Cost of Living Index  Rent Index  \
# 0            Hamilton, Bermuda                145.43      110.87
# 1          Zurich, Switzerland                141.25       66.14
# 2          Geneva, Switzerland                134.83       71.70
# 3           Basel, Switzerland                130.68       49.68
# 4            Bern, Switzerland                128.03       43.57
# ..                         ...                   ...         ...
# 535               Kochi, India                 24.65        6.31
# 536          Coimbatore, India                 24.61        5.35
# 537          Alexandria, Egypt                 23.78        4.34
# 538         Navi Mumbai, India                 23.44        6.25
# 539  Thiruvananthapuram, India                 20.86        5.10
#
#      Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                            128.76           143.47                  158.75
# ...

# %%
frames = [df1, df2]
df = pd.concat(frames).reset_index(drop=True)
df
# Out:
#                  Country  Cost of Living Index  Rent Index  \
# 0      Hamilton, Bermuda                145.43      110.87
# 1    Zurich, Switzerland                141.25       66.14
# 2    Geneva, Switzerland                134.83       71.70
# 3     Basel, Switzerland                130.68       49.68
# 4      Bern, Switzerland                128.03       43.57
# ..                   ...                   ...         ...
# 674            Venezuela                 43.20        9.99
# 675              Vietnam                 37.48       13.22
# 676                Yemen                 53.14        6.71
# 677               Zambia                 33.04        9.26
# 678             Zimbabwe                 45.68        8.75
#
#      Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                            128.76           143.47                  158.75
# 1                            105.03           149.86                  135.76
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 679 entries, 0 to 678
# Data columns (total 7 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Country                         679 non-null    object
#  1   Cost of Living Index            679 non-null    float64
#  2   Rent Index                      679 non-null    float64
#  3   Cost of Living Plus Rent Index  679 non-null    float64
#  4   Groceries Index                 679 non-null    float64
#  5   Restaurant Price Index          679 non-null    float64
#  6   Local Purchasing Power Index    679 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 37.3+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Country                           0
# Cost of Living Index              0
# Rent Index                        0
# Cost of Living Plus Rent Index    0
# Groceries Index                   0
# Restaurant Price Index            0
# Local Purchasing Power Index      0
# dtype: int64

# %% [markdown]
# #Outliers

# %%
#ukuran figure
plt.figure(figsize=(12,8))

#membuat subplot untuk setiap boxplot
plt.subplot(3,2,1)
sns.boxplot(x=df['Cost of Living Index'])
plt.title("Cost of Living Index")

plt.subplot(3,2,2)
sns.boxplot(x=df['Rent Index'])
plt.title("Rent Index")

plt.subplot(3,2,3)
sns.boxplot(x=df['Cost of Living Plus Rent Index'])
plt.title("Cost of Living Plus Rent Index")

plt.subplot(3,2,4)
sns.boxplot(x=df['Groceries Index'])
plt.title("Groceries Index ")

plt.subplot(3,2,5)
sns.boxplot(x=df['Restaurant Price Index'])
plt.title("Restaurant Price Index")

plt.subplot(3,2,6)
sns.boxplot(x=df['Local Purchasing Power Index'])
plt.title("Local Purchasing Power Index")


#Untuk layouting tampilan boxplot
plt.tight_layout()

plt.show()

# %%
df.shape
# Out:
# (679, 7)

# %%
Q1 = df['Cost of Living Index'].quantile(0.25)
Q3 = df['Cost of Living Index'].quantile(0.75)
IQR = Q3-Q1 #Interquartile Range

df = df[~((df['Cost of Living Index']<(Q1-1.5*IQR)) | (df['Cost of Living Index']>(Q3+1.5*IQR)))]

df.shape
# Out:
# (674, 7)

# %%
Q1 = df['Rent Index'].quantile(0.25)
Q3 = df['Rent Index'].quantile(0.75)
IQR = Q3-Q1

df = df[~((df['Rent Index']<(Q1-1.5*IQR)) | (df['Rent Index']>(Q3+1.5*IQR)))]

df.shape
# Out:
# (654, 7)

# %%
Q1 = df['Cost of Living Plus Rent Index'].quantile(0.25)
Q3 = df['Cost of Living Plus Rent Index'].quantile(0.75)
IQR = Q3-Q1

df = df[~((df['Cost of Living Plus Rent Index']<(Q1-1.5*IQR)) | (df['Cost of Living Plus Rent Index']>(Q3+1.5*IQR)))]

df.shape
# Out:
# (654, 7)

# %%
Q1 = df['Groceries Index'].quantile(0.25)
Q3 = df['Groceries Index'].quantile(0.75)
IQR = Q3-Q1

df = df[~((df['Groceries Index']<(Q1-1.5*IQR)) | (df['Groceries Index']>(Q3+1.5*IQR)))]

df.shape
# Out:
# (651, 7)

# %%
Q1 = df['Restaurant Price Index'].quantile(0.25)
Q3 = df['Restaurant Price Index'].quantile(0.75)
IQR = Q3-Q1

df = df[~((df['Restaurant Price Index']<(Q1-1.5*IQR)) | (df['Restaurant Price Index']>(Q3+1.5*IQR)))]

df.shape
# Out:
# (650, 7)

# %%
#ukuran figure
plt.figure(figsize=(12,8))

#membuat subplot untuk setiap boxplot
plt.subplot(3,2,1)
sns.boxplot(x=df['Cost of Living Index'])
plt.title("Cost of Living Index")

plt.subplot(3,2,2)
sns.boxplot(x=df['Rent Index'])
plt.title("Rent Index")

plt.subplot(3,2,3)
sns.boxplot(x=df['Cost of Living Plus Rent Index'])
plt.title("Cost of Living Plus Rent Index")

plt.subplot(3,2,4)
sns.boxplot(x=df['Groceries Index'])
plt.title("Groceries Index ")

plt.subplot(3,2,5)
sns.boxplot(x=df['Restaurant Price Index'])
plt.title("Restaurant Price Index")

plt.subplot(3,2,6)
sns.boxplot(x=df['Local Purchasing Power Index'])
plt.title("Local Purchasing Power Index")


#Untuk layouting tampilan boxplot
plt.tight_layout()

plt.show()

# %% [markdown]
# #Visualisasi

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
df['Country'] = enc.fit_transform(df['Country'])
df.head(30)
# Out:
#     Country  Cost of Living Index  Rent Index  Cost of Living Plus Rent Index  \
# 6       499                123.78       57.25                           91.70
# 8       342                118.24       52.91                           86.73
# 9       440                117.23       49.28                           84.46
# 10      600                114.22       42.39                           79.58
# 11       70                112.31       40.30                           77.58
# 12      312                100.33       24.58                           63.80
# 14      405                 99.73       40.45                           71.14
# 16      148                 97.62       50.66                           74.97
# 17      345                 95.37       61.59                           79.08
# 18       21                 94.99       40.12                           68.53
# 19      252                 94.15       62.82                           79.04
# ...

# %%
df = df.drop("Country", axis = 'columns')
df
# Out:
#      Cost of Living Index  Rent Index  Cost of Living Plus Rent Index  \
# 6                  123.78       57.25                           91.70
# 8                  118.24       52.91                           86.73
# 9                  117.23       49.28                           84.46
# 10                 114.22       42.39                           79.58
# 11                 112.31       40.30                           77.58
# ..                    ...         ...                             ...
# 674                 43.20        9.99                           27.63
# 675                 37.48       13.22                           26.11
# 676                 53.14        6.71                           31.38
# 677                 33.04        9.26                           21.90
# 678                 45.68        8.75                           28.37
#
#      Groceries Index  Restaurant Price Index  Local Purchasing Power Index
# ...

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Melihat Korelasi antar Feature")
plt.show()

# %%
ypoints = df['Cost of Living Plus Rent Index']
xpoints = df['Rent Index']

plt.scatter(xpoints, ypoints)
plt.show()

# %%
ypoints = df['Cost of Living Plus Rent Index']
xpoints = df['Groceries Index']

plt.scatter(xpoints, ypoints)
plt.show()

# %%
ypoints = df['Cost of Living Plus Rent Index']
xpoints = df['Restaurant Price Index']

plt.scatter(xpoints, ypoints)
plt.show()

# %%
ypoints = df['Cost of Living Plus Rent Index']
xpoints = df['Local Purchasing Power Index']

plt.scatter(xpoints, ypoints)
plt.show()

# %% [markdown]
# #Model

# %%
from sklearn.model_selection import train_test_split
x = df.drop(['Cost of Living Plus Rent Index', 'Cost of Living Index'], axis=1) #fitur
y = df['Cost of Living Plus Rent Index'] #target

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3, random_state=123)

# %%
print('Total sampel dari semua dataset : ', (len(x)))
print('Total sampel dari dataset latih : ', (len(x_train)))
print('Total sampel dari dataset uji : ', (len(x_test)))
# Out:
# Total sampel dari semua dataset :  650
# Total sampel dari dataset latih :  455
# Total sampel dari dataset uji :  195

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

model.fit(x_train, y_train) #fit untuk koef regresi dg minimal kesalahan kuadrat

y_train_pred = model.predict(x_train)
y_test_pred = model.predict(x_test)

# %%
#Perhitungan dalam dolar
new_data= {

    'Rent Index': [36.84],
    'Groceries Index': [77.44],
    'Restaurant Price Index' : [72.95],
    'Local Purchasing Power Index' : [104.63]
}

new_df = pd.DataFrame(new_data)

predicted_cost = model.predict(new_df)

print('hasil prediksi harga dari data diatas adalah = ',predicted_cost)
# Out:
# hasil prediksi harga dari data diatas adalah =  [58.35545948]

# %% [markdown]
# #Evaluasi

# %%
#evaluasi performa model regresi linear model pada data pelatihan
model.score(x_train, y_train)
# Out:
# 0.9894069625741994

# %%
df.describe()
# Out:
#        Cost of Living Index  Rent Index  Cost of Living Plus Rent Index  \
# count            650.000000  650.000000                      650.000000
# mean              59.134831   23.447262                       42.009954
# std               20.113257   13.703866                       16.289198
# min               19.920000    2.720000                       12.090000
# 25%               41.030000   11.732500                       27.677500
# 50%               60.485000   21.680000                       42.690000
# 75%               75.342500   32.097500                       54.680000
# max              123.780000   66.000000                       91.700000
#
#        Groceries Index  Restaurant Price Index  Local Purchasing Power Index
# count       650.000000              650.000000                    650.000000
# mean         55.063431               54.020800                     79.934446
# std          20.366221               25.022667                     39.169413
# ...

# %%
df.head(20)
# Out:
#     Cost of Living Index  Rent Index  Cost of Living Plus Rent Index  \
# 6                 123.78       57.25                           91.70
# 8                 118.24       52.91                           86.73
# 9                 117.23       49.28                           84.46
# 10                114.22       42.39                           79.58
# 11                112.31       40.30                           77.58
# 12                100.33       24.58                           63.80
# 14                 99.73       40.45                           71.14
# 16                 97.62       50.66                           74.97
# 17                 95.37       61.59                           79.08
# 18                 94.99       40.12                           68.53
# 19                 94.15       62.82                           79.04
# 20                 93.81       37.07                           66.45
# 22                 92.87       50.30                           72.34
# ...
